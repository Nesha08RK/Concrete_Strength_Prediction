# %% [markdown]
# Objective
#
# The purpose of this notebook is to prepare the dataset for machine learning model training.
#
# We will:
#
# Remove duplicate records
# Separate features and target
# Split the dataset into training and testing sets
# Scale the features (if required)
# Save the processed data for model training

# %%
# import libraries

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Load Dataset
df = pd.read_csv("../Dataset.csv")
df.head()

# Check Dataset Shape
print(df.shape)
# Out:
# (1030, 9)

# %%
# Remove Duplicate Records
print("Duplicate Records:", df.duplicated().sum())

df = df.drop_duplicates()
print("Shape after removing duplicates:", df.shape)
# Out:
# Duplicate Records: 25
# Shape after removing duplicates: (1005, 9)

# %%
# Separate Features and Target

X = df.drop("Strength", axis=1)
y = df["Strength"]

print("Features Shape:", X.shape)
print("Target Shape:", y.shape)
# Out:
# Features Shape: (1005, 8)
# Target Shape: (1005,)

# %%
# Train-Test Split (80-20)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
# Check Split Size
print("Training Features :", X_train.shape)
print("Testing Features  :", X_test.shape)

print("Training Target   :", y_train.shape)
print("Testing Target    :", y_test.shape)
# Out:
# Training Features : (804, 8)
# Testing Features  : (201, 8)
# Training Target   : (804,)
# Testing Target    : (201,)

# %%
# Feature Scaling

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Verify Scaling
print(X_train_scaled[:5])
# Out:
# [[ 2.43672824 -0.83765521 -0.87586539 -1.87288113  3.72010571 -1.56005896
#    1.48730406 -0.67904126]
#  [ 1.89473124 -0.83765521 -0.87586539  2.13224261 -1.02302593 -0.52567253
#   -2.21856469 -0.61484971]
#  [-0.01044116 -0.83765521  0.63871136 -0.99937386  0.96168873  0.01676541
#    1.26349284 -0.67904126]
#  [ 1.51928039 -0.83765521 -0.87586539  1.66761108 -1.02302593 -1.73741933
#   -0.66425137 -0.27784404]
#  [-1.07229319  2.07041858 -0.87586539  0.99389537 -1.02302593  0.03877363
#   -0.99934994 -0.61484971]]

# %%
# Save the Prepared Data 
import os
print(os.getcwd())

X_train.to_csv("../dataset/X_train.csv", index=False)
X_test.to_csv("../dataset/X_test.csv", index=False)

y_train.to_csv("../dataset/y_train.csv", index=False)
y_test.to_csv("../dataset/y_test.csv", index=False)
# Out:
# d:\Final year Project\Concrete_Strength_Prediction\notebooks

# %% [markdown]
# Observations
#
# • Duplicate records were successfully removed from the dataset.
#
# • The dataset was divided into input features (X) and target variable (y).
#
# • The dataset was split into 80% training data and 20% testing data.
#
# • Feature scaling was performed using StandardScaler.
#
# • The processed dataset is ready for machine learning model training.
